# %%
import nltk

# %%
nltk.download('book')

# %%
from nltk.book import *

# %%
text1
text1.concordance("monstrous")
text1.dispersion_plot(["Moby", "Dick", "monstrous", "gone", "life"])

# %%
print(len(text1))
#print(set(text1))
#sorted(set(text1))
print(len(set(text1)))
